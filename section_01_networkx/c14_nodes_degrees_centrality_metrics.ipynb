# %%
import networkx as nx 
from networkx import * 
import matplotlib.pyplot as plt
import sys

# %%
n = 10 # nodes
m = 20 # edges

G = nx.gnm_random_graph(n,m)

print("Nodes Degree Clustering")

for v in nodes(G):
    print("%s %d %f"%(v ,degree(G,v), clustering(G,v)))
# Out:
# Nodes Degree Clustering
# 0 2 0.000000
# 1 4 0.666667
# 2 3 0.333333
# 3 6 0.333333
# 4 6 0.466667
# 5 2 0.000000
# 6 5 0.300000
# 7 4 0.666667
# 8 3 0.666667
# 9 5 0.100000

# %%
plt.figure(figsize=(16,9))
nx.draw(G, with_labels=True, node_size=800, node_color="gold" )
