# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (16,9))
CC = nx.complete_graph(5)
nx.draw_networkx(CC, node_size= 800, node_color="gold")

# %%
nx.clustering(CC)
# Out:
# {0: 1.0, 1: 1.0, 2: 1.0, 3: 1.0, 4: 1.0}

# %%
nx.average_clustering(CC)
# Out:
# 1.0
