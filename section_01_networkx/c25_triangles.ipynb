# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.complete_graph(5)

# %% [markdown]
# print number of triangles at node 0

# %%
plt.figure(figsize=(16,9))
nx.draw(G, node_size = 750, with_labels = True, node_color="y")

# %%
nx.triangles(G, 0)
# Out:
# 6

# %%
nx.triangles(G)
# Out:
# {0: 6, 1: 6, 2: 6, 3: 6, 4: 6}

# %%
list(nx.triangles(G, (0,1)).values())
# Out:
# [6, 6]
